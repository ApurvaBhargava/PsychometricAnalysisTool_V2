# %%
# Preprocessing: text cleaner
import re
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# Dictionary for contraction expansion and changing different spellings of common words to same spellings
contractions = { "ain't": "am not", "aren't": "are not", "can't": "cannot", "can't've": "cannot have",
                "'cause": "because", "could've": "could have", "couldn't": "could not", "couldn't've": "could not have",
                "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hadn't've": "had not have",
                "hasn't": "has not", "haven't": "have not", "he'd": "he would", "he'd've": "he would have", "he'll": "he will",
                "he'll've": "he will have", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will",
                "how's": "how is", "i'd": "i would", "i'd've": "i would have", "i'll": "i will", "i'll've": "i will have",
                "i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have",
                "it'll": "it will", "it'll've": "it will have", "it's": "it is", "let's": "let us", "ma'am": "madam",
                "mayn't": "may not", "might've": "might have", "mightn't": "might not", "mightn't've": "might not have",
                "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not",
                "needn't've": "need not have", "o'clock": "of the clock", "oughtn't": "ought not",
                "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have",
                "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have",
                "so've": "so have", "so's": "so is", "that'd": "that would", "that'd've": "that would have", "that's": "that is",
                "there'd": "there would", "there'd've": "there would have", "there's": "there is", "they'd": "they would",
                "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are",
                "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have",
                "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not",
                "what'll": "what will", "what'll've": "what will have", "what're": "what are", "what's": "what is",
                "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did",
                "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have",
                "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have",
                "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not",
                "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                "y'all'd've": "you all would have", "y'all're": "you all are", "y'all've": "you all have", "you'd": "you would",
                "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are",
                "you've": "you have", "ve": "have", "favor":"favour", "favorite":"favourite", "color":"colour"}

contrac_pattern = re.compile(r'\b(' + '|'.join(contractions.keys()) + r')\b')

def text_cleaner(text):
    text = text.lower()
    text = contrac_pattern.sub(lambda x: contractions[x.group()], text)
    text = re.sub('[^A-Za-z0-9 ]+', '', text)
    return text

def text_cleaner_two(text):
    text = text.lower()
    text = contrac_pattern.sub(lambda x: contractions[x.group()], text)
    text = re.sub('[^A-Za-z0-9 ]+', '', text)
    final_text = ""
    for word in text.split(" "):
        final_text = final_text + stemmer.stem(word) + " "
    return final_text

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# Read basic chatbot question/statement - responses from databook.xlsx
df = pd.read_excel('databook.xlsx', sheetname='Sheet1')
print(df.columns)

ds_basic = []

for i in range(782):
    temp_list = ["", ""]
    temp_list[0] = df['context'][i]
    temp_list[1] = df['target'][i]
    ds_basic.append(temp_list)

for i in range(len(ds_basic)):
    ds_basic[i][0] = text_cleaner(ds_basic[i][0])
    ds_basic[i][1] = text_cleaner(ds_basic[i][1])
# Out:
# C:\Users\apurv\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# Index(['context', 'target'], dtype='object')

# %%
# Read psychometrics related question/statement - responses from psychometricsqa.xlsx

df = pd.read_excel('psychometricsqa.xlsx', sheetname='Sheet1')
print(df.columns)

ds_psycho = []

for i in range(58):
    temp_list = ["", ""]
    temp_list[0] = df['Question'][i]
    temp_list[1] = df['Answer'][i]
    ds_psycho.append(temp_list)

for i in range(len(ds_psycho)):
    ds_psycho[i][0] = text_cleaner(ds_psycho[i][0])
# Out:
# Index(['Question', 'Answer'], dtype='object')
# C:\Users\apurv\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
import os

# Read other general chatbot question/statement - responses from .txt files

ds_fancy = []

path = "favourites/{}.txt"
for i in range(1, 15):
    with open(path.format(i), "r") as f:
        lines = f.read().splitlines()
        ds_fancy.append(lines)

path = "food/{}.txt"
for i in range(1, 24):
    with open(path.format(i), "r") as f:
        lines = f.read().splitlines()
        ds_fancy.append(lines)

path = "greetings/{}.txt"
for i in range(1, 18):
    with open(path.format(i), "r") as f:
        lines = f.read().splitlines()
        ds_fancy.append(lines)

path = "health/{}.txt"
for i in range(1, 5):
    with open(path.format(i), "r") as f:
        lines = f.read().splitlines()
        ds_fancy.append(lines)

path = "lifedeath/{}.txt"
for i in range(1, 7):
    with open(path.format(i), "r") as f:
        lines = f.read().splitlines()
        ds_fancy.append(lines)

path = "newstv/{}.txt"
for i in range(1, 14):
    with open(path.format(i), "r") as f:
        lines = f.read().splitlines()
        ds_fancy.append(lines)

path = "progcomp/{}.txt"
for i in range(1, 13):
    with open(path.format(i), "r") as f:
        lines = f.read().splitlines()
        ds_fancy.append(lines)

path = "weather/{}.txt"
for i in range(1, 11):
    with open(path.format(i), "r") as f:
        lines = f.read().splitlines()
        ds_fancy.append(lines)

for i in range(len(ds_fancy)):
    for j in range(len(ds_fancy[i])):
        ds_fancy[i][j] = text_cleaner(ds_fancy[i][j])

# %%
import chatterbot
from chatterbot import response_selection
from chatterbot import ChatBot
#from chatterbot.comparisons import JaccardSimilarity
from chatterbot.comparisons import LevenshteinDistance
from chatterbot.comparisons import SynsetDistance
#from chatterbot.comparisons import SentimentComparison
from chatterbot.trainers import ListTrainer

# Create a new instance of a ChatBot
bot = ChatBot(
    'Example Bot',
    read_only=True,
    storage_adapter="chatterbot.storage.SQLStorageAdapter",
    logic_adapters=[
        {
            "import_path": "chatterbot.logic.BestMatch",
            "statement_comparison_function": LevenshteinDistance,
            'maximum_similarity_threshold': 0.3,
            'default_response': 'I am sorry, but I do not understand.'
        }
    ],
    preprocessors=['chatterbot.preprocessors.clean_whitespace']
)

trainer = ListTrainer(bot)

for i in range(len(ds_basic)):
    trainer.train(ds_basic[i])

for i in range(len(ds_fancy)):
    trainer.train(ds_fancy[i])

for i in range(len(ds_psycho)):
    trainer.train(ds_psycho[i])

'''
# Create a new instance of a ChatBot
bot = ChatBot(
    'Example Bot',
    read_only=True,
    storage_adapter="chatterbot.storage.SQLStorageAdapter",
    logic_adapters=[
        {
            "import_path": "chatterbot.logic.BestMatch",
            "statement_comparison_function": LevenshteinDistance,
            'default_response': 'I am sorry, but I do not understand.',
            'maximum_similarity_threshold': 0.2,
            "response_selection_method": chatterbot.response_selection.get_random_response
        }
    ],
    preprocessors=['chatterbot.preprocessors.clean_whitespace'],
)
'''
# Out:
# [nltk_data] Error loading averaged_perceptron_tagger: <urlopen error
# [nltk_data]     [Errno 11001] getaddrinfo failed>
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# ...

# %% [markdown]
# ### Testing the trained bot

# %%
# Get a response for some unexpected input
while True:
    message = input('You: ')
    message = text_cleaner(message)
    if message.strip().lower() != 'bye':
        reply = bot.get_response(message)
        reply.text = reply.text.capitalize()
        reply.text += "."
        print('ChatBot: ', reply)
        #print('Response category: ', reply.get_tags())
    if message.strip().lower() == 'bye':
        print('ChatBot: Bye')
        break
# Out:
# You: Hello
# ChatBot:  Greetings.
# You: How are you?
# ChatBot:  Great thanks.
# You: What is your favourite number?
# ChatBot:  I do not really have an opinion about that.
# You: What is IRT?
# ...

# %% [markdown]
# ### Add code for ending conversation

# %%
def check_str(string, sub_str):
    if (string.find(sub_str) == -1):
        return False
    else:
        return True

# %%
ender = ['bye', 'goodbye', 'finish the interview', 'quit the interview', 'end the interview', 'it was great talking to you', 'byebye', 'end this chat', 'quit this chat', 'finish this chat', 'done talking']

# Get a response for some unexpected input
while True:
    message = input('You: ')
    message = text_cleaner(message)
    if check_str(message, ender[0]) or check_str(message, ender[1]) or check_str(message, ender[2]) or check_str(message, ender[3]) or check_str(message, ender[4]) or check_str(message, ender[5]) or check_str(message, ender[6]) or check_str(message, ender[7]) or check_str(message, ender[8]) or check_str(message, ender[9]):
        print('ChatBot: It was nice talking to you. Goodbye!')
        break
    else:
        reply = bot.get_response(message)
        reply.text = reply.text.capitalize()
        reply.text += "."
        print('ChatBot: ', reply)
        #print('Response category: ', reply.get_tags())
# Out:
# You: Hey there
# ChatBot:  Hello.
# You: I wanted to ask
# ChatBot:  Sure no problem.
# You: What is weather
# ChatBot:  I am sorry, but i do not understand..
# You: Never mind
# ChatBot:  I am sorry, but i do not understand..
# You: What is your favourite season
# ChatBot:  My favourite season is winter.
# You: Do you like summer?
# ChatBot:  We are all here to help.
# You: What about summer
# ChatBot:  No i do not like summer it is my least favourite summer.
# You: okay, what is intelligence
# ChatBot:  Intelligence has been defined in many ways, including: the capacity for logic, understanding, self-awareness, learning, emotional knowledge, reasoning, planning, creativity, critical thinking, and problem solving. more generally, it can be described as the ability to perceive or infer information, and to retain it as knowledge to be applied towards adaptive behaviors within an environment or context..
# You: what is iq
# ...

# %% [markdown]
# ### Adapting to the user's response to a question, based on correctness of response and question difficulty
#
# <img src="Images/ask_ques.png" alt="drawing" style="float:center"/>

# %%
from math import ceil

def ask_question(highscore, n, index):
    if n == num_ques:
        # select question of median difficulty
        index = ceil(len(ques_list)/2)
        ques_list[index][2] = False
        return ques_dict[ques_list[index][0]], index
    elif n > 0:
        flag = False
        if highscore:
            while index<=len(ques_list)-1 and ques_list[index][2]!=True:
                index += 1
                flag = True
                if index>len(ques_list)-1:
                    flag=False
                    index-=1
                    break
            if not flag:
                while index>=0 and ques_list[index][2]!=True:
                    index -= 1
        else:
            while index>=0 and ques_list[index][2]!=True:
                index -= 1
                flag = True
                if index<0:
                    flag=False
                    index+=1
                    break
            if not flag:
                while index<=len(ques_list)-1 and ques_list[index][2]!=True:
                    index += 1
        ques_list[index][2] = False
        return ques_dict[ques_list[index][0]], index
    else:
        return "END", -1

# %%
# Test 1
ques_list = [['q1',4,True], ['q2',3,True], ['q3',5,True], ['q4',4,True], ['q5',2,True], ['q6',3,True], ['q7',1,True], ['q8',6,True]]
ques_list = sorted(ques_list, key=lambda x: x[1])
print(ques_list)
ques_dict = {"q1":"how", "q2":"why", "q3":"what", "q4":"when", "q5":"where", "q6":"who", "q7":"whose", "q8":"whom"}
num_ques = 5

highscores =[True, True, False, True, False, False, True]
n=5
i=-1
for val in highscores:
    q, i = ask_question(val, n, i)
    n-=1
    print(q)
# Out:
# [['q7', 1, True], ['q5', 2, True], ['q2', 3, True], ['q6', 3, True], ['q1', 4, True], ['q4', 4, True], ['q3', 5, True], ['q8', 6, True]]
# how
# when
# who
# what
# why
# END
# END

# %%
#Test 2
ques_list = [[3, '1', True], [2, '2', True], [1, '3', True], [5, '3', True], [4, '4', True], [0, '5', True]]
ques_list = sorted(ques_list, key=lambda x:x[1])
print(ques_list)
ques_dict = {0: 'ghnr', 1: 'how are you responding', 2: 'how are you', 3: 'do you love your parents', 4: 'write what you see', 5: 'pink city'}
expected = {0: 'oyuih', 1: 'nicely great poor bad good polite', 2: 'i am good great well very sad', 3: 'yes no ', 4: 'write what you see', 5: 'jaipur '}
difficulty = {0: '5', 1: '3', 2: '2', 3: '1', 4: '4', 5: '3'}
num_ques=6

highscores =[True, False, True, True, True, True, True]
n=6
i=-1
for val in highscores:
    q, i = ask_question(val, n, i)
    n-=1
    print(q)
# Out:
# [[3, '1', True], [2, '2', True], [1, '3', True], [5, '3', True], [4, '4', True], [0, '5', True]]
# pink city
# how are you responding
# write what you see
# ghnr
# how are you
# do you love your parents
# END

# %% [markdown]
# ### Scoring response on the basis of similarity to expected response.
#
# <img src="Images/score_ans.png" alt="drawing" style="float:center"/>

# %%
# cosine similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
def cosine_sim(strs):
    cossim= []
    if len(strs[0].split())==1 or len(strs[0].split())==1:
        vectorizer = CountVectorizer(strs, stop_words = {'a', 'an', 'the'}, ngram_range=(1,1))
        vectorizer.fit(strs)
        vectors = vectorizer.transform(strs).toarray()
        cossim.append(cosine_similarity(vectors)[0][1])
        cossim.append(0)
    else:
        for i in range(1,3):
            vectorizer = CountVectorizer(strs, stop_words = {'a', 'an', 'the'}, ngram_range=(i,i))
            vectorizer.fit(strs)
            vectors = vectorizer.transform(strs).toarray()
            cossim.append(cosine_similarity(vectors)[0][1])
    return cossim

# Jaccard similarity
def jaccard_sim(str1, str2):
    a = set(str1.split())
    b = set(str2.split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
from math import ceil
def score_answer(strs, difficulty):
    strs[0] = text_cleaner_two(strs[0])
    strs[1] = text_cleaner_two(strs[1])
    cossim = cosine_sim(strs)
    score = cossim[0]*6 + jaccard_sim(strs[0], strs[1])*2.4
    if cossim[1]<0.2:
        score += cossim[1]
    elif cossim[1]<=0.3:
        score += 0.4
    elif cossim[1]<=0.5:
        score += 0.8
    elif cossim[1]<=0.7:
        score += 1
    else:
        score += 1.6
    return ceil(score)*difficulty

# %%
print(score_answer(["AI has always been the friend of all humans.", "AI and humans have always been friendly"], 5))
# Out:
# 30

# %%
print(score_answer(["i will be going to jaipur", "i am going to jaipur"], 6))
# Out:
# 42

# %% [markdown]
# ## Trials before implementation

# %%
# Test 1: Simple chatbot

from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
import os

chatbot = ChatBot('Psycho')
trainer = ListTrainer(chatbot)

for files in os.listdir('C:/Users/apurv/english/'):
    data = open('C:/Users/apurv/english/' + files, 'r').readlines()
    trainer.train(data)

while True:
    message = input('You: ')
    if message.strip().lower() != 'bye':
        reply = chatbot.get_response(message)
        print('ChatBot: ', reply)
    if message.strip().lower() == 'bye':
        print('ChatBot: Bye')
        break

# %%
# Test 3: Try nltk.corpus.wordnet for synonyms. (Rejected)

import nltk
from nltk.corpus import wordnet

# Then, we're going to use the term "program" to find synsets like so:
syns = wordnet.synsets("program")

# An example of a synset:
print(syns[0].name())

# Just the word:
print(syns[0].lemmas()[0].name())

# Definition of that first synset:
print(syns[0].definition())

# Examples of the word in use in sentences:
print(syns[0].examples())

# All the synonyms
print(syns)

# Similarity between two verbs
w1 = wordnet.synset('run.v.01') # v here denotes the tag verb
w2 = wordnet.synset('sprint.v.01')
print(w1.wup_similarity(w2))

# Similarity between two nouns
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('boat.n.01') # n denotes noun
print(w1.wup_similarity(w2))

# %%
# Test 4: Try thesaurus for synonyms. (Selected)

from thesaurus import Word

w = Word('diligent')
print(w.synonyms('all', form='common', relevance=3))
print(w.synonyms(relevance=2))
print(w.synonyms(form='informal', relevance=1))
print(len(w.synonyms('all', form='common', relevance=3)))

print(w.synonyms(relevance=3))
print(w.synonyms()[2])

# %%
# Test 5: Generation of sentences with similar meaning

import nltk
from thesaurus import Word
from random import randint

#question = "What choice do you have about what happens in your life?"
#expected_ans = "I think I control my choices actively and decide what happens in my life."
actual_ans = "I believe that I can manage my own decisions and choices."
ans1 = ""

tagged = nltk.pos_tag(nltk.word_tokenize(actual_ans))

for x in range(len(tagged)):
    if bool(random.getrandbits(1)):
        if tagged[x][1]=='JJ' or tagged[x][1]=='JJR' or tagged[x][1]=='JJS' or tagged[x][1]=='NN' or tagged[x][1]=='NNS' or tagged[x][1]=='RB' or tagged[x][1]=='RBR' or tagged[x][1]=='RBS' or tagged[x][1]=='VB' or tagged[x][1]=='VBD' or tagged[x][1]=='VBG' or tagged[x][1]=='VBN' or tagged[x][1]=='VBP' or tagged[x][1]=='VBZ':
            w = Word(tagged[x][0])
            print(tagged[x][0])
            print(tagged[x][1])
            synonym_list = w.synonyms(relevance=3)
            synonym_list.append(tagged[x][0])
            num_synonyms = len(synonym_list)
            if num_synonyms != 0:
                index = randint(0, num_synonyms-1)
                print(index)
                ans1 = ans1 + synonym_list[index] + " "
            else:
                ans1 = ans1 + tagged[x][0] + " "
        else:
            ans1 = ans1 + tagged[x][0] + " "
    else:
        ans1 = ans1 + tagged[x][0] + " "
print(ans1)

# %%
# Test 6 : Training chatbot using Ubuntu corpus
#chatterbot.trainers.UbuntuCorpusTrainer(chatbot, **kwargs)[source]

import logging
from chatterbot import ChatBot
from chatterbot.trainers import UbuntuCorpusTrainer

# Enable info level logging
logging.basicConfig(level=logging.INFO)

chatbot = ChatBot('Example Bot')

trainer = UbuntuCorpusTrainer(chatbot)

# Start by training our bot with the Ubuntu corpus data
trainer.train()

# Now let's get a response to a greeting
response = chatbot.get_response('How are you doing today?')
print(response)
